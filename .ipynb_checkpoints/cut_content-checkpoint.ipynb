# %%
import jieba

def remove_space(element): 
    return "".join(element.split())

for x in xrange(1,10):
    txt = 'new/{}.txt'  
    f = open(txt.format(x),'r').read()
    
    
#txt = 'my/15.txt'  
#f = open(txt,'r').read()
    cut = remove_space(f) 
    jieba.set_dictionary('C:\Users\BIG DATA\Desktop\project\jieba\dict.txt.big.txt')
    jieba.load_userdict("C:\Users\BIG DATA\Desktop\project\userdict.txt")
    
    words = jieba.cut(cut, cut_all=False)
#filename = 'jie/15.txt'
#with open(filename, 'w') as f2:
    for word in words:
        print word

#   filename = 'abc/{}.txt'.format(x)
#    with open(filename,'w') as f2:   
#        for word in words:
#            f2.write((word+'\n').encode('utf8'))
# Out:
# Building prefix dict from C:\Users\BIG DATA\Desktop\project\jieba\dict.txt.big.txt ...
# DEBUG:jieba:Building prefix dict from C:\Users\BIG DATA\Desktop\project\jieba\dict.txt.big.txt ...
# Dumping model to file cache c:\users\bigdat~1\appdata\local\temp\jieba.u77112760da007e433e08c17edb921161.cache
# DEBUG:jieba:Dumping model to file cache c:\users\bigdat~1\appdata\local\temp\jieba.u77112760da007e433e08c17edb921161.cache
# Loading model cost 2.071 seconds.
# DEBUG:jieba:Loading model cost 2.071 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# Building prefix dict from C:\Users\BIG DATA\Desktop\project\jieba\dict.txt.big.txt ...
# DEBUG:jieba:Building prefix dict from C:\Users\BIG DATA\Desktop\project\jieba\dict.txt.big.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u77112760da007e433e08c17edb921161.cache
# ...
